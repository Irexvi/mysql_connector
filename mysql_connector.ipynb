# %%
import mysql.connector

# %%
dbase = mysql.connector.connect(user='USER', password='PASS',
                              host='HOST',
                              database='DATABASE')

# %%
cursor = dbase.cursor()

# %%
query = ("SELECT * from authors")

# %%
cursor.execute(query)

# %%
cursor.fetchall()
# Out:
# [(1, 'Juan Rulfo', 'MEX'),
#  (2, 'Gabriel Garcia Marquez', 'COL'),
#  (3, 'Juan Gabriel Vasquez', 'COL'),
#  (4, 'Julio Cortazar', 'ARG'),
#  (5, 'Isabel Allende', 'CHI'),
#  (6, 'Octavio Paz', 'MEX'),
#  (7, 'Juan Carlos Onetti', 'URU'),
#  (16, 'Pablo Neruda', None)]
